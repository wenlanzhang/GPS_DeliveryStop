# %%
import pandas as pd
import os
import glob

# %%
Source = '/Users/zhangwenlan/Downloads/Tongji_RA/Data/Process/Processed/8CC(DeliveryStop)/TrueStopCheck/'
file = '/Users/zhangwenlan/Downloads/Tongji_RA/Data/Process/Processed/8CC(DeliveryStop)/Processed/TrueStop.csv'

# %%
df = pd.read_csv('/Users/zhangwenlan/Downloads/Tongji_RA/Data/Process/Processed/8CC(DeliveryStop)/Processed/TrueStop.csv')  # Read file

# %%
df
# print(df.head)
# Out:
#      FileID  StopID Car Plate  StartRow   EndRow            StartTime  \
# 0       0.0    56.0  湘A-E2628    4445.0   4559.0  2017-04-23 09:37:00
# 1       0.0    60.0  湘A-E2628    4598.0   6105.0  2017-04-23 12:09:00
# 2       1.0    47.0  湘A-A0355    5668.0   6567.0  2017-05-01 19:34:00
# 3       1.0   260.0  湘A-A0355   24964.0  26240.0  2017-05-31 22:30:00
# 4       2.0    26.0  湘A-C1827    1285.0   1771.0  2017-04-24 17:31:00
# ..      ...     ...       ...       ...      ...                  ...
# 474    58.0   262.0  湘A-E2547   17809.0  18117.0  2017-05-20 01:11:33
# 475    58.0   425.0  湘A-E2547   28325.0  28889.0  2017-06-04 22:39:25
# 476    58.0   504.0  湘A-E2547   32799.0  32802.0  2017-06-18 13:14:30
# 477    58.0   518.0  湘A-E2547   33371.0  33376.0  2017-06-18 22:41:12
# 478    58.0   533.0  湘A-E2547   33687.0  34061.0  2017-06-19 03:57:14
#
#                  EndTime  Duration(min)  Time Delta    MeanLat     MeanLon  \
# ...

# %%
dfNew = df.loc[(55 < df['FileID']) & (df['FileID'] <= 61)]
# dfNew = df.loc[df['FileID'] <= 7]

# %%
dfNew
# Out:
#      FileID  StopID Car Plate  StartRow   EndRow            StartTime  \
# 456    56.0    16.0  湘A-C2661     820.0   1369.0  2017-04-17 16:52:21
# 457    56.0    37.0  湘A-C2661    2249.0   2541.0  2017-04-18 08:19:31
# 458    56.0   107.0  湘A-C2661    7367.0   7706.0  2017-04-30 01:56:00
# 459    56.0   135.0  湘A-C2661   12483.0  12798.0  2017-05-03 01:37:00
# 460    56.0   283.0  湘A-C2661   27750.0  28989.0  2017-06-04 14:24:39
# 461    56.0   291.0  湘A-C2661   29131.0  29477.0  2017-06-05 13:46:04
# 462    56.0   473.0  湘A-C2661   46650.0  47100.0  2017-08-16 02:18:52
# 463    56.0   640.0  湘A-C2661   68220.0  68958.0  2017-08-30 22:07:36
# 464    56.0   657.0  湘A-C2661   69435.0  70184.0  2017-08-31 20:18:59
# 465    57.0    30.0  湘A-A3902    1790.0   2858.0  2017-05-03 19:44:26
# 466    57.0   237.0  湘A-A3902   30671.0  31798.0  2017-05-31 20:46:37
# 467    57.0   269.0  湘A-A3902   33559.0  33870.0  2017-06-03 15:36:08
# ...

# %%
dfNew.to_csv('/Users/zhangwenlan/Downloads/Tongji_RA/Data/Process/Processed/8CC(DeliveryStop)/TrueStopCheck/' + '5561.csv', index=False)

# %%
dfsum.loc[dfsum['FileID'] == i].iloc[0]
# Out:
# FileID                                                              1
# StopID                                                              0
# Car Plate                                                    湘A-A0355
# StartRow                                                            0
# EndRow                                                           1779
# StartTime                                         2017-04-27 17:02:00
# EndTime                                           2017-04-28 23:11:00
# Duration(min)                                                    1809
# Time Delta                                                          0
# MeanLat                                                       28.2759
# MeanLon                                                       112.674
# Distance(m)                                                         0
# Location            湖南省长沙市宁乡县银洲路,距长沙市康荣特种陶瓷有限公司 约109米,距长沙天和钻具机械有限公...
# ...

# %%
dfsum.loc[dfsum['FileID'] == i].iloc[0]['Car Plate']
# Out:
# '湘A-A0355'

# %%
file = dfsum.loc[dfsum['FileID'] == i].iloc[0]['Car Plate']

# %%
print(file)
# Out:
# 湘A-A0355
